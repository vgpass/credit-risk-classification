# %%
# MODULE 20 - CREDIT RISK CLASSIFICATION MODEL - USING RAW DATA
# Vincent Passanisi

# Import the modules
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report

# %% [markdown]
# ---

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %% [markdown]
# ### Step 1: Read the `lending_data.csv` data from the `Resources` folder into a Pandas DataFrame.

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
# YOUR CODE HERE!
loan_df = pd.read_csv(Path('Resources/lending_data.csv'))
# Review the DataFrame
# YOUR CODE HERE!
loan_df.head()
# Out:
#    loan_size  interest_rate  borrower_income  debt_to_income  num_of_accounts  \
# 0    10700.0          7.672            52800        0.431818                5
# 1     8400.0          6.692            43600        0.311927                3
# 2     9000.0          6.963            46100        0.349241                3
# 3    10700.0          7.664            52700        0.430740                5
# 4    10800.0          7.698            53000        0.433962                5
#
#    derogatory_marks  total_debt  loan_status
# 0                 1       22800            0
# 1                 0       13600            0
# 2                 0       16100            0
# 3                 1       22700            0
# 4                 1       23000            0

# %%
# Identifying shape of the data
loan_df.shape
# Out:
# (77536, 8)

# %%
# Getting additional information on the data
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77536 entries, 0 to 77535
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   loan_size         77536 non-null  float64
#  1   interest_rate     77536 non-null  float64
#  2   borrower_income   77536 non-null  int64
#  3   debt_to_income    77536 non-null  float64
#  4   num_of_accounts   77536 non-null  int64
#  5   derogatory_marks  77536 non-null  int64
#  6   total_debt        77536 non-null  int64
#  7   loan_status       77536 non-null  int64
# dtypes: float64(3), int64(5)
# memory usage: 4.7 MB

# %%
# Looking at column headers
loan_df.columns
# Out:
# Index(['loan_size', 'interest_rate', 'borrower_income', 'debt_to_income',
#        'num_of_accounts', 'derogatory_marks', 'total_debt', 'loan_status'],
#       dtype='object')

# %%
# Data statistics for evaluation purposes.
loan_df.describe()
# Out:
#           loan_size  interest_rate  borrower_income  debt_to_income  \
# count  77536.000000   77536.000000     77536.000000    77536.000000
# mean    9805.562577       7.292333     49221.949804        0.377318
# std     2093.223153       0.889495      8371.635077        0.081519
# min     5000.000000       5.250000     30000.000000        0.000000
# 25%     8700.000000       6.825000     44800.000000        0.330357
# 50%     9500.000000       7.172000     48100.000000        0.376299
# 75%    10400.000000       7.528000     51400.000000        0.416342
# max    23800.000000      13.235000    105200.000000        0.714829
#
#        num_of_accounts  derogatory_marks    total_debt   loan_status
# count     77536.000000      77536.000000  77536.000000  77536.000000
# mean          3.826610          0.392308  19221.949804      0.032243
# std           1.904426          0.582086   8371.635077      0.176646
# min           0.000000          0.000000      0.000000      0.000000
# ...

# %%
# Calculate the sum total of the outstanding loans
total = loan_df['loan_size'].sum()
total
# Out:
# 760284100.0

# %%
# Calculate the total of the loans in default
defaults = loan_df.loc[loan_df['loan_status'] == 1, ['loan_size']].sum()
defaults
# Out:
# loan_size    46269500.0
# dtype: float64

# %%
# Calculating the percent of oustanding loans in default
percent_default = defaults / total *100
percent_default
# Out:
# loan_size    6.085817
# dtype: float64

# %% [markdown]
# ### Step 2: Create the labels set (`y`)  from the “loan_status” column, and then create the features (`X`) DataFrame from the remaining columns.

# %%
# Separate the data into labels and features

# Separate the y variable, the labels
# YOUR CODE HERE!]
y = loan_df['loan_status']
# Separate the X variable, the features
# YOUR CODE HERE!
X = loan_df.drop(columns='loan_status')

# %%
# Review the y variable Series
# YOUR CODE HERE!
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: loan_status, dtype: int64

# %%
# Review the X variable DataFrame
# YOUR CODE HERE!
X.head()
# Out:
#    loan_size  interest_rate  borrower_income  debt_to_income  num_of_accounts  \
# 0    10700.0          7.672            52800        0.431818                5
# 1     8400.0          6.692            43600        0.311927                3
# 2     9000.0          6.963            46100        0.349241                3
# 3    10700.0          7.664            52700        0.430740                5
# 4    10800.0          7.698            53000        0.433962                5
#
#    derogatory_marks  total_debt
# 0                 1       22800
# 1                 0       13600
# 2                 0       16100
# 3                 1       22700
# 4                 1       23000

# %% [markdown]
# ### Step 3: Check the balance of the labels variable (`y`) by using the `value_counts` function.

# %%
# Check the balance of our target values
# YOUR CODE HERE!
y.value_counts()
# Out:
# 0    75036
# 1     2500
# Name: loan_status, dtype: int64

# %% [markdown]
# ### Step 4: Split the data into training and testing datasets by using `train_test_split`.

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
# YOUR CODE HERE!
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ---

# %% [markdown]
# ## Create a Logistic Regression Model with the Original Data

# %% [markdown]
# ###  Step 1: Fit a logistic regression model by using the training data (`X_train` and `y_train`).

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
# YOUR CODE HERE!
lr_model = LogisticRegression(solver='lbfgs', random_state=1)
# Fit the model using training data
# YOUR CODE HERE!
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
# Validating the model using score.
print(f"Training Data Score: {lr_model.score(X_train, y_train)}")
print(f"Testing Data Score: {lr_model.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.9921240885954051
# Testing Data Score: 0.9918489475856377

# %% [markdown]
# ### Step 2: Save the predictions on the testing data labels by using the testing feature data (`X_test`) and the fitted model.

# %%
# Make a prediction using the testing data
# YOUR CODE HERE!
loan_predictions = lr_model.predict(X_test)
pd.DataFrame({"Prediction": loan_predictions, "Actual": y_test})
# Out:
#        Prediction  Actual
# 60914           0       0
# 36843           0       0
# 1966            0       0
# 70137           0       0
# 27237           0       0
# ...           ...     ...
# 45639           0       0
# 11301           0       0
# 51614           0       0
# 4598            0       0
# 2793            0       0
#
# [19384 rows x 2 columns]

# %% [markdown]
# ### Step 3: Evaluate the model’s performance by doing the following:
#
# * Calculate the accuracy score of the model.
#
# * Generate a confusion matrix.
#
# * Print the classification report.

# %%
# Print the balanced_accuracy score of the model
# YOUR CODE HERE!
loan_acc = balanced_accuracy_score(y_test, loan_predictions)
loan_acc
# Out:
# 0.9520479254722232

# %%
# Generate a confusion matrix for the model
# YOUR CODE HERE!
c_matrix = confusion_matrix(y_test, loan_predictions)
print(c_matrix)
# Out:
# [[18663   102]
#  [   56   563]]

# %%
# Print the classification report for the model
# YOUR CODE HERE!
loan_test_report = classification_report(y_test, loan_predictions)
print(loan_test_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     18765
#            1       0.85      0.91      0.88       619
#
#     accuracy                           0.99     19384
#    macro avg       0.92      0.95      0.94     19384
# weighted avg       0.99      0.99      0.99     19384

# %% [markdown]
# ### Step 4: Answer the following question.

# %% [markdown]
# **Question:** How well does the logistic regression model predict both the `0` (healthy loan) and `1` (high-risk loan) labels?
#
# **Answer:** The prediction model shows an extremely high accuracy at 99%. Precision in predicting loan defaults is 85%, which is high, but additional steps may need to be put in place to assess a potential default once a loan is flagged as a potential for default. Precision for healthy loans is nearly perfect. The accuracy of the model is pretty high at 95.2%.

# %% [markdown]
# ---

# %% [markdown]
# ## Predict a Logistic Regression Model with Resampled Training Data

# %% [markdown]
# ### Step 1: Use the `RandomOverSampler` module from the imbalanced-learn library to resample the data. Be sure to confirm that the labels have an equal number of data points.

# %%
# Import the RandomOverSampler module form imbalanced-learn
from imblearn.over_sampling import RandomOverSampler

# Instantiate the random oversampler model
# # Assign a random_state parameter of 1 to the model
# YOUR CODE HERE!
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X, y)


# Fit the original training data to the random_oversampler model
# YOUR CODE HERE!
ros.fit(X_train, y_train)
# Out:
# RandomOverSampler(random_state=1)

# %%
# Count the distinct values of the resampled labels data
# YOUR CODE HERE!
y_resampled.value_counts()
# Out:
# 0    75036
# 1    75036
# Name: loan_status, dtype: int64

# %% [markdown]
# ### Step 2: Use the `LogisticRegression` classifier and the resampled data to fit the model and make predictions.

# %%
# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
# YOUR CODE HERE!
ros_model = LogisticRegression(solver='lbfgs', random_state=1)

# Fit the model using the resampled training data
# YOUR CODE HERE!
ros_model.fit(X_resampled, y_resampled)

# Make a prediction using the testing data
# YOUR CODE HERE!
ros_predictions = ros_model.predict(X_test)

# %% [markdown]
# ### Step 3: Evaluate the model’s performance by doing the following:
#
# * Calculate the accuracy score of the model.
#
# * Generate a confusion matrix.
#
# * Print the classification report.

# %%
# Print the balanced_accuracy score of the model 
# YOUR CODE HERE!
ros_acc = balanced_accuracy_score(y_test, ros_predictions)
ros_acc
# Out:
# 0.9936781215845847

# %%
# Generate a confusion matrix for the model
# YOUR CODE HERE!
ros_c_matrix = confusion_matrix(y_test, ros_predictions)
print(ros_c_matrix)
# Out:
# [[18649   116]
#  [    4   615]]

# %%
# Print the classification report for the model
# YOUR CODE HERE!
loan_ros_report = classification_report(y_test, ros_predictions)
print(loan_ros_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     18765
#            1       0.84      0.99      0.91       619
#
#     accuracy                           0.99     19384
#    macro avg       0.92      0.99      0.95     19384
# weighted avg       0.99      0.99      0.99     19384

# %% [markdown]
# ### Step 4: Answer the following question

# %% [markdown]
# **Question:** How well does the logistic regression model, fit with oversampled data, predict both the `0` (healthy loan) and `1` (high-risk loan) labels?
#
# **Answer:** For the oversampled data, the model was extremely accurate at 99%. The recall indicator shows that the model accurately predicted 99% of the loans that actually did default. For the oversampled data, there were only 4 false positives and 116 false negatives out of 19,384 loans. The model would be highly reliable in predicting loans that could potentially default.
